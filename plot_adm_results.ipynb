# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
def gallery(array, ncols=3):
    nindex, height, width, intensity = array.shape
    nrows = nindex//ncols
    assert nindex == nrows*ncols
    # want result.shape = (height*nrows, width*ncols, intensity)
    result = (array.reshape(nrows, ncols, height, width, intensity)
              .swapaxes(1,2)
              .reshape(height*nrows, width*ncols, intensity))
    return result

# %%
f ='samples_36x512x512x3.npz'
path = 'output/class_cond_4.0/'

# %%
f ='samples_36x512x512x3.npz'
path = '../ilvr_adm/output_uncond/'

# %%
f ='samples_36x256x256x3.npz'
path = 'test_results/256_from_scratch/'

# %%
imgs = np.load(path+f)
final_imgs = imgs['arr_0'] 
print('No of images: {}'.format(len(final_imgs))) 
#print('Labels in the images: {}'.format(imgs['arr_1'])) 

plt.figure(figsize = (30,30))
plt.imshow(gallery(final_imgs,6))
# plt.imshow(np.hstack(imgs['arr_0'][0]))
# plt.imshow(imgs['arr_0'][5])
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# No of images: 36

# %%
print('Plot each image')
# for im in final_imgs: 
#     plt.figure(figsize = (10,10))
#     plt.imshow(im)
#     plt.xticks([])
#     plt.yticks([])
#     plt.show()
#     plt.clf()
# Out:
# Plot each image
